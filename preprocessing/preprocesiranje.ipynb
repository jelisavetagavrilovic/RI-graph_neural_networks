# %%
import os
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
node_data = pd.read_csv('../data/node_data.csv', index_col=0)

# %%
G = nx.Graph()

# dodavanje grana
edges_file = "../data/facebook/facebook_combined.txt"
edges = pd.read_csv(edges_file, sep=' ', header=None, names=['node1', 'node2'])
G.add_edges_from(edges.values)

# dodavanje atributa cvorovima
for node_id, attributes in node_data.iterrows():
    nx.set_node_attributes(G, {node_id: attributes.to_dict()})

# %%
directory = "../data/facebook/facebook"  

node_to_ego = {}

# ucitavanje podataka za ego korisnike
for filename in os.listdir(directory):
    if filename.endswith(".circles"):
        ego_id = int(filename.split('.')[0])
        
        circles_file = os.path.join(directory, filename)
        with open(circles_file, 'r') as file:
            circles = [line.strip().split('\t') for line in file]
        
        for circle in circles: 
            for node in circle[1:]:
                node_id = int(node)
                if node_id not in node_to_ego:
                    node_to_ego[node_id] = set()  
                node_to_ego[node_id].add(ego_id) 

node_to_ego = {node: list(egos) for node, egos in node_to_ego.items()}

# %%
print(f"Broj čvorova u grafu: {G.number_of_nodes()}")
print(f"Broj ivica u grafu: {G.number_of_edges()}")
# Out:
# Broj čvorova u grafu: 4039
# Broj ivica u grafu: 88234

# %%
print(f"Broj atributa: {len(G.nodes[0])}")
# Out:
# Broj atributa: 2255

# %%
import csv

output_csv_file = "node_to_ego.csv"

with open(output_csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)

    # zaglavlje
    writer.writerow(['node_id', 'ego_id'])

    # podaci za svaki cvor
    for node_id, egos in node_to_ego.items():
        for ego_id in egos:
            writer.writerow([node_id, ego_id])

# %% [markdown]
# ## ciljna promenljiva

# %%
# mapiranje ego_id u indeks

unique_ego_ids = sorted(list(set([ego_id for egos in node_to_ego.values() for ego_id in egos])))
ego_id_to_index = {ego_id: i for i, ego_id in enumerate(unique_ego_ids)}

# dodavanje ciljne promenljive kao atributa "target" svakom cvoru
for node in G.nodes:
    target_vector = [0] * len(unique_ego_ids)  
    if node in node_to_ego:
        for ego_id in node_to_ego[node]:
            target_index = ego_id_to_index[ego_id] 
            target_vector[target_index] = 1 
            
    G.nodes[node]['target'] = target_vector

# %%
output_csv_file = "ego_to_index.csv"

with open(output_csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)

    # zaglavlje
    writer.writerow(['ego_id', 'index'])

    # podaci za svaki cvor
    for ego_id, index in ego_id_to_index.items():
        writer.writerow([ego_id, index])

# %%
import pickle

# serijalizacija grafa
with open("graph.pkl", "wb") as f:
    pickle.dump(G, f)

# %%
G.nodes[17]
# Out:
# {'0 birthday;anonymized feature 0': 1,
#  '0 birthday;anonymized feature 1003': 0,
#  '0 birthday;anonymized feature 1172': 0,
#  '0 birthday;anonymized feature 2': 0,
#  '0 birthday;anonymized feature 206': 0,
#  '0 birthday;anonymized feature 208': 0,
#  '0 birthday;anonymized feature 209': 0,
#  '0 birthday;anonymized feature 376': 0,
#  '0 birthday;anonymized feature 6': 0,
#  '0 birthday;anonymized feature 729': 0,
#  '1 birthday;anonymized feature 0': 0,
#  '1 birthday;anonymized feature 1': 0,
#  '1 birthday;anonymized feature 1004': 0,
#  '1 birthday;anonymized feature 2': 0,
#  '1 birthday;anonymized feature 207': 0,
#  '1 birthday;anonymized feature 208': 0,
#  '1 birthday;anonymized feature 3': 0,
#  '1 birthday;anonymized feature 730': 0,
#  '1 education;concentration;id;anonymized feature 14': 0,
#  '10 birthday;anonymized feature 1006': 0,
#  '10 birthday;anonymized feature 211': 0,
#  '10 birthday;anonymized feature 7': 0,
#  '10 education;classes;id;anonymized feature 10': 0,
#  '10 education;concentration;id;anonymized feature 215': 0,
#  '10 education;concentration;id;anonymized feature 339': 0,
#  '10 education;concentration;id;anonymized feature 384': 0,
#  '10 education;school;id;anonymized feature 370': 0,
#  '10 education;year;id;anonymized feature 253': 0,
#  '100 education;school;id;anonymized feature 446': 0,
#  '100 education;school;id;anonymized feature 538': 0,
#  '100 education;school;id;anonymized feature 788': 0,
#  '100 education;year;id;anonymized feature 68': 0,
#  '100 languages;id;anonymized feature 100': 0,
#  '100 last_name;anonymized feature 271': 0,
#  '100 work;start_date;anonymized feature 157': 0,
#  '101 education;school;id;anonymized feature 315': 0,
#  '101 education;school;id;anonymized feature 447': 0,
#  '101 education;type;anonymized feature 53': 0,
#  '101 education;year;id;anonymized feature 69': 0,
#  '101 languages;id;anonymized feature 101': 0,
#  '101 last_name;anonymized feature 110': 0,
#  '101 work;start_date;anonymized feature 334': 0,
#  '102 education;school;id;anonymized feature 228': 0,
#  '102 education;school;id;anonymized feature 455': 0,
#  '102 education;type;anonymized feature 54': 0,
#  '102 education;year;id;anonymized feature 257': 0,
#  '102 languages;id;anonymized feature 102': 0,
#  '102 last_name;anonymized feature 272': 0,
#  '102 work;start_date;anonymized feature 310': 0,
#  '103 education;school;id;anonymized feature 448': 0,
#  '103 education;school;id;anonymized feature 789': 0,
#  '103 education;type;anonymized feature 55': 0,
#  '103 education;year;id;anonymized feature 258': 0,
#  '103 languages;id;anonymized feature 103': 0,
#  '103 last_name;anonymized feature 273': 0,
#  '103 work;start_date;anonymized feature 200': 0,
#  '104 education;school;id;anonymized feature 229': 0,
#  '104 education;school;id;anonymized feature 790': 0,
#  '104 education;year;id;anonymized feature 543': 0,
#  '104 education;year;id;anonymized feature 71': 0,
#  '104 last_name;anonymized feature 104': 0,
#  '104 last_name;anonymized feature 274': 0,
#  '104 work;start_date;anonymized feature 202': 0,
#  '105 education;school;id;anonymized feature 449': 0,
#  '105 education;school;id;anonymized feature 791': 0,
#  '105 education;year;id;anonymized feature 259': 0,
#  '105 education;year;id;anonymized feature 58': 0,
#  '105 last_name;anonymized feature 105': 0,
#  '105 last_name;anonymized feature 275': 0,
#  '106 education;school;id;anonymized feature 450': 0,
#  '106 education;school;id;anonymized feature 792': 0,
#  '106 education;year;id;anonymized feature 59': 0,
#  '106 education;year;id;anonymized feature 72': 0,
#  '106 last_name;anonymized feature 106': 0,
#  '106 last_name;anonymized feature 276': 0,
#  '107 education;school;id;anonymized feature 451': 0,
#  '107 education;school;id;anonymized feature 793': 0,
#  '107 education;year;id;anonymized feature 544': 0,
#  '107 first_name;anonymized feature 545': 0,
#  '107 last_name;anonymized feature 107': 0,
#  '107 last_name;anonymized feature 277': 0,
#  '108 education;school;id;anonymized feature 452': 0,
#  '108 education;school;id;anonymized feature 794': 0,
#  '108 education;year;id;anonymized feature 60': 0,
#  '108 first_name;anonymized feature 1065': 0,
#  '108 last_name;anonymized feature 108': 0,
#  '108 locale;anonymized feature 127': 0,
#  '109 education;school;id;anonymized feature 453': 0,
#  '109 education;school;id;anonymized feature 795': 0,
#  '109 education;year;id;anonymized feature 61': 0,
#  '109 first_name;anonymized feature 1213': 0,
#  '109 last_name;anonymized feature 109': 0,
#  '109 locale;anonymized feature 278': 0,
#  '11 birthday;anonymized feature 212': 0,
#  '11 birthday;anonymized feature 377': 0,
#  '11 education;classes;id;anonymized feature 11': 0,
#  '11 education;classes;id;anonymized feature 756': 0,
#  '11 education;concentration;id;anonymized feature 216': 0,
#  '11 education;concentration;id;anonymized feature 386': 0,
#  '11 education;school;id;anonymized feature 340': 0,
#  '11 education;school;id;anonymized feature 348': 0,
#  '11 education;year;id;anonymized feature 1270': 0,
#  '110 education;school;id;anonymized feature 230': 0,
#  '110 education;school;id;anonymized feature 796': 0,
#  '110 education;year;id;anonymized feature 62': 0,
#  '110 first_name;anonymized feature 546': 0,
#  '110 last_name;anonymized feature 110': 0,
#  '110 location;id;anonymized feature 128': 0,
#  '111 education;school;id;anonymized feature 315': 0,
#  '111 education;school;id;anonymized feature 460': 0,
#  '111 education;year;id;anonymized feature 63': 0,
#  '111 first_name;anonymized feature 1214': 0,
#  '111 last_name;anonymized feature 111': 0,
#  '111 location;id;anonymized feature 129': 0,
#  '112 education;school;id;anonymized feature 454': 0,
#  '112 education;school;id;anonymized feature 797': 0,
#  '112 education;year;id;anonymized feature 64': 0,
#  '112 first_name;anonymized feature 1215': 0,
#  '112 last_name;anonymized feature 112': 0,
#  '112 location;id;anonymized feature 279': 0,
#  '113 education;school;id;anonymized feature 455': 0,
#  '113 education;school;id;anonymized feature 461': 0,
#  '113 education;year;id;anonymized feature 65': 0,
#  '113 first_name;anonymized feature 1216': 0,
#  '113 last_name;anonymized feature 113': 0,
#  '113 location;id;anonymized feature 280': 0,
#  '114 education;school;id;anonymized feature 456': 0,
#  '114 education;school;id;anonymized feature 798': 0,
#  '114 education;year;id;anonymized feature 66': 0,
#  '114 first_name;anonymized feature 1217': 0,
#  '114 last_name;anonymized feature 114': 0,
#  '114 location;id;anonymized feature 281': 0,
#  '115 education;school;id;anonymized feature 457': 0,
#  '115 education;school;id;anonymized feature 799': 0,
#  '115 education;year;id;anonymized feature 68': 0,
#  '115 first_name;anonymized feature 1218': 0,
#  '115 last_name;anonymized feature 115': 0,
#  '115 location;id;anonymized feature 133': 0,
#  '116 education;school;id;anonymized feature 232': 0,
#  '116 education;school;id;anonymized feature 800': 0,
#  '116 education;year;id;anonymized feature 69': 0,
#  '116 first_name;anonymized feature 1079': 0,
#  '116 last_name;anonymized feature 116': 0,
#  '116 location;id;anonymized feature 84': 0,
#  '117 education;school;id;anonymized feature 458': 0,
#  '117 education;school;id;anonymized feature 801': 0,
#  '117 education;year;id;anonymized feature 70': 0,
#  '117 gender;anonymized feature 77': 0,
#  '117 last_name;anonymized feature 117': 0,
#  '117 location;id;anonymized feature 176': 0,
#  '118 education;school;id;anonymized feature 459': 0,
#  '118 education;school;id;anonymized feature 802': 0,
#  '118 education;year;id;anonymized feature 72': 0,
#  '118 gender;anonymized feature 78': 0,
#  '118 last_name;anonymized feature 118': 0,
#  '118 location;id;anonymized feature 282': 0,
#  '119 education;school;id;anonymized feature 460': 0,
#  '119 education;school;id;anonymized feature 803': 0,
#  '119 first_name;anonymized feature 1063': 0,
#  '119 hometown;id;anonymized feature 1219': 0,
#  '119 last_name;anonymized feature 119': 0,
#  '119 location;id;anonymized feature 283': 0,
#  '12 birthday;anonymized feature 378': 0,
#  '12 education;classes;id;anonymized feature 12': 0,
#  '12 education;concentration;id;anonymized feature 1007': 0,
#  '12 education;concentration;id;anonymized feature 13': 0,
#  '12 education;concentration;id;anonymized feature 14': 0,
#  '12 education;concentration;id;anonymized feature 217': 0,
#  '12 education;school;id;anonymized feature 341': 0,
#  '12 education;type;anonymized feature 53': 0,
#  '12 education;year;id;anonymized feature 1271': 0,
#  '120 education;school;id;anonymized feature 461': 0,
#  '120 education;school;id;anonymized feature 804': 0,
#  '120 first_name;anonymized feature 545': 0,
#  '120 hometown;id;anonymized feature 82': 0,
#  '120 last_name;anonymized feature 120': 0,
#  '120 location;id;anonymized feature 284': 0,
#  '121 education;school;id;anonymized feature 462': 0,
#  '121 education;school;id;anonymized feature 805': 0,
#  '121 first_name;anonymized feature 1064': 0,
#  '121 hometown;id;anonymized feature 1220': 0,
#  '121 last_name;anonymized feature 121': 0,
#  '121 location;id;anonymized feature 138': 0,
#  '122 education;school;id;anonymized feature 463': 0,
#  '122 education;school;id;anonymized feature 469': 0,
#  '122 first_name;anonymized feature 1065': 0,
#  '122 hometown;id;anonymized feature 86': 0,
#  '122 last_name;anonymized feature 122': 0,
#  '122 work;employer;id;anonymized feature 225': 0,
#  '123 education;school;id;anonymized feature 464': 0,
#  '123 education;school;id;anonymized feature 470': 0,
#  '123 first_name;anonymized feature 1066': 0,
#  '123 hometown;id;anonymized feature 283': 0,
#  '123 last_name;anonymized feature 123': 0,
#  '123 work;employer;id;anonymized feature 285': 0,
#  '124 education;school;id;anonymized feature 465': 0,
#  '124 education;school;id;anonymized feature 806': 0,
#  '124 first_name;anonymized feature 621': 0,
#  '124 hometown;id;anonymized feature 297': 0,
#  '124 last_name;anonymized feature 124': 0,
#  '124 work;employer;id;anonymized feature 286': 0,
#  '125 education;school;id;anonymized feature 466': 0,
#  '125 education;school;id;anonymized feature 807': 0,
#  '125 first_name;anonymized feature 353': 0,
#  '125 hometown;id;anonymized feature 1221': 0,
#  '125 locale;anonymized feature 125': 0,
#  '125 work;employer;id;anonymized feature 287': 0,
#  '126 education;school;id;anonymized feature 467': 0,
#  '126 education;school;id;anonymized feature 808': 0,
#  '126 first_name;anonymized feature 1067': 0,
#  '126 hometown;id;anonymized feature 618': 0,
#  '126 locale;anonymized feature 126': 0,
#  '126 work;employer;id;anonymized feature 288': 0,
#  '127 education;school;id;anonymized feature 468': 0,
#  '127 education;school;id;anonymized feature 809': 0,
#  '127 first_name;anonymized feature 1068': 0,
#  '127 hometown;id;anonymized feature 1222': 0,
#  '127 locale;anonymized feature 127': 1,
#  '127 work;employer;id;anonymized feature 289': 0,
#  '128 education;school;id;anonymized feature 469': 0,
#  '128 education;school;id;anonymized feature 810': 0,
#  '128 first_name;anonymized feature 892': 0,
#  '128 hometown;id;anonymized feature 1223': 0,
#  '128 location;id;anonymized feature 128': 0,
#  '128 work;employer;id;anonymized feature 290': 0,
#  '129 education;school;id;anonymized feature 470': 0,
#  '129 education;school;id;anonymized feature 811': 0,
#  '129 first_name;anonymized feature 1069': 0,
#  '129 hometown;id;anonymized feature 619': 0,
#  '129 location;id;anonymized feature 129': 1,
#  '129 work;employer;id;anonymized feature 291': 0,
#  '13 birthday;anonymized feature 379': 0,
#  '13 birthday;anonymized feature 733': 0,
#  '13 education;concentration;id;anonymized feature 1009': 0,
#  '13 education;concentration;id;anonymized feature 13': 0,
#  '13 education;concentration;id;anonymized feature 213': 0,
#  '13 education;concentration;id;anonymized feature 312': 0,
#  '13 education;school;id;anonymized feature 342': 0,
#  '13 education;type;anonymized feature 54': 0,
#  '13 education;year;id;anonymized feature 254': 0,
#  '130 education;school;id;anonymized feature 471': 0,
#  '130 education;school;id;anonymized feature 812': 0,
#  '130 first_name;anonymized feature 1070': 0,
#  '130 languages;id;anonymized feature 90': 0,
#  '130 location;id;anonymized feature 130': 0,
#  '130 work;employer;id;anonymized feature 292': 0,
#  '131 education;school;id;anonymized feature 472': 0,
#  '131 education;school;id;anonymized feature 813': 0,
#  '131 first_name;anonymized feature 1071': 0,
#  '131 languages;id;anonymized feature 91': 0,
#  '131 location;id;anonymized feature 131': 0,
#  '131 work;employer;id;anonymized feature 293': 0,
#  '132 education;school;id;anonymized feature 473': 0,
#  '132 education;school;id;anonymized feature 814': 0,
#  '132 first_name;anonymized feature 1072': 0,
#  '132 languages;id;anonymized feature 92': 0,
#  '132 location;id;anonymized feature 132': 0,
#  '132 work;employer;id;anonymized feature 52': 0,
#  '133 education;school;id;anonymized feature 474': 0,
#  '133 education;school;id;anonymized feature 815': 0,
#  '133 first_name;anonymized feature 1073': 0,
#  '133 languages;id;anonymized feature 1224': 0,
#  '133 location;id;anonymized feature 133': 0,
#  '133 work;end_date;anonymized feature 157': 0,
#  '134 education;school;id;anonymized feature 233': 0,
#  '134 education;school;id;anonymized feature 816': 0,
#  '134 first_name;anonymized feature 1074': 0,
#  '134 languages;id;anonymized feature 913': 0,
#  '134 location;id;anonymized feature 134': 0,
#  '134 work;end_date;anonymized feature 294': 0,
#  '135 education;school;id;anonymized feature 475': 0,
#  '135 education;school;id;anonymized feature 817': 0,
#  '135 first_name;anonymized feature 1075': 0,
#  '135 languages;id;anonymized feature 94': 0,
#  '135 location;id;anonymized feature 135': 0,
#  '135 work;end_date;anonymized feature 166': 0,
#  '136 education;school;id;anonymized feature 476': 0,
#  '136 education;school;id;anonymized feature 481': 0,
#  '136 first_name;anonymized feature 1076': 0,
#  '136 languages;id;anonymized feature 572': 0,
#  '136 location;id;anonymized feature 136': 0,
#  '136 work;end_date;anonymized feature 170': 0,
#  '137 education;school;id;anonymized feature 234': 0,
#  '137 education;school;id;anonymized feature 818': 0,
#  '137 first_name;anonymized feature 1077': 0,
#  '137 languages;id;anonymized feature 1225': 0,
#  '137 location;id;anonymized feature 88': 0,
#  '137 work;end_date;anonymized feature 171': 0,
#  '138 education;school;id;anonymized feature 235': 0,
#  '138 education;school;id;anonymized feature 819': 0,
#  '138 first_name;anonymized feature 1078': 0,
#  '138 languages;id;anonymized feature 573': 0,
#  '138 location;id;anonymized feature 137': 0,
#  '138 work;location;id;anonymized feature 295': 0,
#  '139 education;school;id;anonymized feature 477': 0,
#  '139 education;school;id;anonymized feature 820': 0,
#  '139 first_name;anonymized feature 1079': 0,
#  '139 languages;id;anonymized feature 97': 0,
#  '139 location;id;anonymized feature 138': 0,
#  '139 work;location;id;anonymized feature 128': 0,
#  '14 birthday;anonymized feature 380': 0,
#  '14 birthday;anonymized feature 734': 0,
#  '14 education;concentration;id;anonymized feature 14': 0,
#  '14 education;concentration;id;anonymized feature 385': 0,
#  '14 education;concentration;id;anonymized feature 388': 0,
#  '14 education;degree;id;anonymized feature 220': 0,
#  '14 education;school;id;anonymized feature 343': 0,
#  '14 education;type;anonymized feature 55': 0,
#  '14 education;year;id;anonymized feature 62': 0,
#  '140 education;school;id;anonymized feature 236': 0,
#  '140 education;school;id;anonymized feature 478': 0,
#  '140 first_name;anonymized feature 1080': 0,
#  '140 languages;id;anonymized feature 100': 0,
#  '140 work;employer;id;anonymized feature 139': 0,
#  '140 work;location;id;anonymized feature 296': 0,
#  '141 education;school;id;anonymized feature 479': 0,
#  '141 education;school;id;anonymized feature 486': 0,
#  '141 first_name;anonymized feature 1081': 0,
#  '141 languages;id;anonymized feature 103': 0,
#  '141 work;employer;id;anonymized feature 140': 0,
#  '141 work;location;id;anonymized feature 84': 0,
#  '142 education;school;id;anonymized feature 480': 0,
#  '142 education;school;id;anonymized feature 821': 0,
#  '142 first_name;anonymized feature 1082': 0,
#  '142 last_name;anonymized feature 1226': 0,
#  '142 work;employer;id;anonymized feature 141': 0,
#  '142 work;location;id;anonymized feature 297': 0,
#  '143 education;school;id;anonymized feature 481': 0,
#  '143 education;school;id;anonymized feature 822': 0,
#  '143 first_name;anonymized feature 900': 0,
#  '143 last_name;anonymized feature 1227': 0,
#  '143 work;employer;id;anonymized feature 142': 0,
#  '143 work;location;id;anonymized feature 298': 0,
#  '144 education;school;id;anonymized feature 482': 0,
#  '144 education;school;id;anonymized feature 823': 0,
#  '144 first_name;anonymized feature 1083': 0,
#  '144 last_name;anonymized feature 1228': 0,
#  '144 work;employer;id;anonymized feature 143': 0,
#  '144 work;position;id;anonymized feature 183': 0,
#  '145 education;school;id;anonymized feature 483': 0,
#  '145 education;school;id;anonymized feature 824': 0,
#  '145 first_name;anonymized feature 1084': 0,
#  '145 last_name;anonymized feature 1229': 0,
#  '145 work;employer;id;anonymized feature 144': 0,
#  '145 work;position;id;anonymized feature 299': 0,
#  '146 education;school;id;anonymized feature 236': 0,
#  '146 education;school;id;anonymized feature 825': 0,
#  '146 first_name;anonymized feature 1085': 0,
#  '146 last_name;anonymized feature 106': 0,
#  '146 work;employer;id;anonymized feature 145': 0,
#  '146 work;position;id;anonymized feature 300': 0,
#  '147 education;school;id;anonymized feature 484': 0,
#  '147 education;school;id;anonymized feature 826': 0,
#  '147 gender;anonymized feature 77': 0,
#  '147 last_name;anonymized feature 578': 0,
#  '147 work;employer;id;anonymized feature 146': 0,
#  '147 work;position;id;anonymized feature 301': 0,
#  '148 education;school;id;anonymized feature 485': 0,
#  '148 education;school;id;anonymized feature 827': 0,
#  '148 gender;anonymized feature 78': 0,
#  '148 last_name;anonymized feature 1230': 0,
#  '148 work;employer;id;anonymized feature 147': 0,
#  '148 work;position;id;anonymized feature 302': 0,
#  '149 education;school;id;anonymized feature 486': 0,
#  '149 education;school;id;anonymized feature 828': 0,
#  '149 hometown;id;anonymized feature 129': 0,
#  '149 last_name;anonymized feature 1231': 0,
#  '149 work;employer;id;anonymized feature 50': 0,
#  '149 work;position;id;anonymized feature 303': 0,
#  '15 birthday;anonymized feature 381': 0,
#  '15 birthday;anonymized feature 735': 0,
#  '15 education;concentration;id;anonymized feature 14': 0,
#  '15 education;concentration;id;anonymized feature 15': 0,
#  '15 education;concentration;id;anonymized feature 214': 0,
#  '15 education;degree;id;anonymized feature 313': 0,
#  '15 education;school;id;anonymized feature 344': 0,
#  '15 education;with;id;anonymized feature 350': 0,
#  '15 education;year;id;anonymized feature 1272': 0,
#  '150 education;school;id;anonymized feature 487': 0,
#  '150 education;school;id;anonymized feature 829': 0,
#  '150 hometown;id;anonymized feature 1086': 0,
#  '150 last_name;anonymized feature 1232': 0,
#  '150 work;employer;id;anonymized feature 148': 0,
#  '150 work;position;id;anonymized feature 304': 0,
#  '151 education;school;id;anonymized feature 488': 0,
#  '151 education;school;id;anonymized feature 830': 0,
#  '151 hometown;id;anonymized feature 1087': 0,
#  '151 last_name;anonymized feature 1233': 0,
#  '151 work;employer;id;anonymized feature 149': 0,
#  '151 work;position;id;anonymized feature 192': 0,
#  '152 education;school;id;anonymized feature 489': 0,
#  '152 education;school;id;anonymized feature 831': 0,
#  '152 hometown;id;anonymized feature 280': 0,
#  '152 last_name;anonymized feature 581': 0,
#  '152 work;employer;id;anonymized feature 150': 0,
#  '152 work;position;id;anonymized feature 193': 0,
#  '153 education;school;id;anonymized feature 490': 0,
#  '153 education;school;id;anonymized feature 832': 0,
#  '153 hometown;id;anonymized feature 1088': 0,
#  '153 last_name;anonymized feature 1234': 0,
#  '153 work;employer;id;anonymized feature 151': 0,
#  '153 work;start_date;anonymized feature 157': 0,
#  '154 education;school;id;anonymized feature 316': 0,
#  '154 education;school;id;anonymized feature 833': 0,
#  '154 hometown;id;anonymized feature 935': 0,
#  '154 last_name;anonymized feature 582': 0,
#  '154 work;employer;id;anonymized feature 152': 0,
#  '154 work;start_date;anonymized feature 305': 0,
#  '155 education;school;id;anonymized feature 237': 0,
#  '155 education;school;id;anonymized feature 834': 0,
#  '155 hometown;id;anonymized feature 1089': 0,
#  '155 last_name;anonymized feature 1115': 0,
#  '155 work;employer;id;anonymized feature 153': 0,
#  '155 work;start_date;anonymized feature 306': 0,
#  '156 education;school;id;anonymized feature 491': 0,
#  '156 education;school;id;anonymized feature 835': 0,
#  '156 hometown;id;anonymized feature 176': 0,
#  '156 last_name;anonymized feature 1235': 0,
#  '156 work;employer;id;anonymized feature 52': 0,
#  '156 work;start_date;anonymized feature 307': 0,
#  '157 education;school;id;anonymized feature 492': 0,
#  '157 education;school;id;anonymized feature 836': 0,
#  '157 hometown;id;anonymized feature 1090': 0,
#  '157 last_name;anonymized feature 1236': 0,
#  '157 work;employer;id;anonymized feature 154': 0,
#  '157 work;start_date;anonymized feature 308': 0,
#  '158 education;school;id;anonymized feature 493': 0,
#  '158 education;school;id;anonymized feature 837': 0,
#  '158 hometown;id;anonymized feature 1091': 0,
#  '158 last_name;anonymized feature 593': 0,
#  '158 work;employer;id;anonymized feature 155': 0,
#  '158 work;start_date;anonymized feature 309': 0,
#  '159 education;school;id;anonymized feature 239': 0,
#  '159 education;school;id;anonymized feature 494': 0,
#  '159 hometown;id;anonymized feature 1092': 0,
#  '159 last_name;anonymized feature 1237': 0,
#  '159 work;employer;id;anonymized feature 156': 0,
#  '159 work;start_date;anonymized feature 310': 0,
#  '16 birthday;anonymized feature 382': 0,
#  '16 birthday;anonymized feature 736': 0,
#  '16 education;concentration;id;anonymized feature 15': 0,
#  '16 education;concentration;id;anonymized feature 16': 0,
#  '16 education;concentration;id;anonymized feature 389': 0,
#  '16 education;concentration;id;anonymized feature 762': 0,
#  '16 education;degree;id;anonymized feature 22': 0,
#  '16 education;school;id;anonymized feature 345': 0,
#  '16 education;year;id;anonymized feature 1273': 0,
#  '16 education;year;id;anonymized feature 59': 0,
#  '160 education;school;id;anonymized feature 495': 0,
#  '160 education;school;id;anonymized feature 838': 0,
#  '160 hometown;id;anonymized feature 1093': 0,
#  '160 last_name;anonymized feature 595': 0,
#  '160 work;end_date;anonymized feature 157': 1,
#  '160 work;start_date;anonymized feature 202': 0,
#  '161 education;school;id;anonymized feature 496': 0,
#  '161 education;school;id;anonymized feature 839': 0,
#  '161 hometown;id;anonymized feature 1094': 0,
#  '161 last_name;anonymized feature 1238': 0,
#  '161 work;end_date;anonymized feature 158': 0,
#  '162 education;school;id;anonymized feature 238': 0,
#  '162 education;school;id;anonymized feature 840': 0,
#  '162 hometown;id;anonymized feature 283': 0,
#  '162 last_name;anonymized feature 1239': 0,
#  '162 work;end_date;anonymized feature 159': 0,
#  '163 education;school;id;anonymized feature 44': 0,
#  '163 education;school;id;anonymized feature 841': 0,
#  '163 hometown;id;anonymized feature 1095': 0,
#  '163 last_name;anonymized feature 1240': 0,
#  '163 work;end_date;anonymized feature 160': 0,
#  '164 education;school;id;anonymized feature 497': 0,
#  '164 education;school;id;anonymized feature 842': 0,
#  '164 hometown;id;anonymized feature 1096': 0,
#  '164 last_name;anonymized feature 1241': 0,
#  '164 work;end_date;anonymized feature 161': 0,
#  '165 education;school;id;anonymized feature 498': 0,
#  '165 education;school;id;anonymized feature 503': 0,
#  '165 hometown;id;anonymized feature 1097': 0,
#  '165 last_name;anonymized feature 1242': 0,
#  '165 work;end_date;anonymized feature 162': 0,
#  '166 education;school;id;anonymized feature 499': 0,
#  '166 education;school;id;anonymized feature 843': 0,
#  '166 hometown;id;anonymized feature 1098': 0,
#  '166 last_name;anonymized feature 1243': 0,
#  '166 work;end_date;anonymized feature 163': 0,
#  '167 education;school;id;anonymized feature 500': 0,
#  '167 education;school;id;anonymized feature 844': 0,
#  '167 hometown;id;anonymized feature 617': 0,
#  '167 last_name;anonymized feature 1244': 0,
#  '167 work;end_date;anonymized feature 164': 0,
#  '168 education;school;id;anonymized feature 501': 0,
#  '168 education;school;id;anonymized feature 504': 0,
#  '168 hometown;id;anonymized feature 284': 0,
#  '168 last_name;anonymized feature 602': 0,
#  '168 work;end_date;anonymized feature 165': 0,
#  '169 education;school;id;anonymized feature 502': 0,
#  '169 education;school;id;anonymized feature 845': 0,
#  '169 hometown;id;anonymized feature 1099': 0,
#  '169 last_name;anonymized feature 1139': 0,
#  '169 work;end_date;anonymized feature 166': 0,
#  '17 birthday;anonymized feature 737': 0,
#  '17 education;concentration;id;anonymized feature 1008': 0,
#  '17 education;concentration;id;anonymized feature 1174': 0,
#  '17 education;concentration;id;anonymized feature 17': 0,
#  '17 education;concentration;id;anonymized feature 215': 0,
#  '17 education;concentration;id;anonymized feature 383': 0,
#  '17 education;degree;id;anonymized feature 221': 0,
#  '17 education;school;id;anonymized feature 346': 0,
#  '17 education;year;id;anonymized feature 1274': 0,
#  '17 education;year;id;anonymized feature 255': 0,
#  '170 education;school;id;anonymized feature 240': 0,
#  '170 education;school;id;anonymized feature 846': 0,
#  '170 hometown;id;anonymized feature 1100': 0,
#  '170 last_name;anonymized feature 1245': 0,
#  '170 work;end_date;anonymized feature 167': 0,
#  '171 education;school;id;anonymized feature 503': 0,
#  '171 education;school;id;anonymized feature 847': 0,
#  '171 languages;id;anonymized feature 90': 0,
#  '171 last_name;anonymized feature 1246': 0,
#  '171 work;end_date;anonymized feature 168': 0,
#  '172 education;school;id;anonymized feature 504': 0,
#  '172 education;school;id;anonymized feature 848': 0,
#  '172 languages;id;anonymized feature 571': 0,
#  '172 locale;anonymized feature 126': 0,
#  '172 work;end_date;anonymized feature 169': 0,
#  '173 education;school;id;anonymized feature 505': 0,
#  '173 education;school;id;anonymized feature 849': 0,
#  '173 languages;id;anonymized feature 92': 0,
#  '173 locale;anonymized feature 127': 0,
#  '173 work;end_date;anonymized feature 170': 0,
#  '174 education;school;id;anonymized feature 506': 0,
#  '174 education;school;id;anonymized feature 850': 0,
#  '174 languages;id;anonymized feature 1101': 0,
#  '174 locale;anonymized feature 1247': 0,
#  '174 work;end_date;anonymized feature 171': 0,
#  '175 education;school;id;anonymized feature 507': 0,
#  '175 education;school;id;anonymized feature 851': 0,
#  '175 languages;id;anonymized feature 913': 0,
#  '175 locale;anonymized feature 1248': 0,
#  '175 work;end_date;anonymized feature 172': 0,
#  '176 education;school;id;anonymized feature 508': 0,
#  '176 education;school;id;anonymized feature 852': 0,
#  '176 languages;id;anonymized feature 1102': 0,
#  '176 locale;anonymized feature 1249': 0,
#  '176 work;location;id;anonymized feature 129': 0,
#  '177 education;school;id;anonymized feature 509': 0,
#  '177 education;school;id;anonymized feature 853': 0,
#  '177 languages;id;anonymized feature 94': 0,
#  '177 location;id;anonymized feature 128': 0,
#  '177 work;location;id;anonymized feature 173': 0,
#  '178 education;school;id;anonymized feature 317': 0,
#  '178 education;school;id;anonymized feature 854': 0,
#  '178 languages;id;anonymized feature 572': 0,
#  '178 location;id;anonymized feature 1250': 0,
#  '178 work;location;id;anonymized feature 174': 0,
#  '179 education;school;id;anonymized feature 510': 0,
#  '179 education;school;id;anonymized feature 855': 0,
#  '179 languages;id;anonymized feature 95': 0,
#  '179 location;id;anonymized feature 129': 0,
#  '179 work;location;id;anonymized feature 132': 0,
#  '18 birthday;anonymized feature 738': 0,
#  '18 education;concentration;id;anonymized feature 1009': 0,
#  '18 education;concentration;id;anonymized feature 13': 0,
#  '18 education;concentration;id;anonymized feature 18': 0,
#  '18 education;concentration;id;anonymized feature 216': 0,
#  '18 education;concentration;id;anonymized feature 338': 0,
#  '18 education;degree;id;anonymized feature 23': 0,
#  '18 education;school;id;anonymized feature 347': 0,
#  '18 education;year;id;anonymized feature 257': 0,
#  '18 education;year;id;anonymized feature 60': 0,
#  '180 education;school;id;anonymized feature 511': 0,
#  '180 education;school;id;anonymized feature 856': 0,
#  '180 languages;id;anonymized feature 97': 0,
#  '180 location;id;anonymized feature 296': 0,
#  '180 work;location;id;anonymized feature 175': 1,
#  '181 education;school;id;anonymized feature 512': 0,
#  '181 education;school;id;anonymized feature 857': 0,
#  '181 languages;id;anonymized feature 265': 0,
#  '181 location;id;anonymized feature 174': 0,
#  '181 work;location;id;anonymized feature 176': 0,
#  '182 education;school;id;anonymized feature 243': 0,
#  '182 education;school;id;anonymized feature 858': 0,
#  '182 languages;id;anonymized feature 98': 0,
#  '182 location;id;anonymized feature 1251': 0,
#  '182 work;location;id;anonymized feature 177': 0,
#  '183 education;school;id;anonymized feature 513': 0,
#  '183 education;school;id;anonymized feature 514': 0,
#  '183 languages;id;anonymized feature 100': 0,
#  '183 location;id;anonymized feature 613': 0,
#  '183 work;location;id;anonymized feature 178': 0,
#  '184 education;school;id;anonymized feature 514': 0,
#  '184 education;school;id;anonymized feature 859': 0,
#  '184 languages;id;anonymized feature 101': 0,
#  '184 location;id;anonymized feature 281': 0,
#  '184 work;location;id;anonymized feature 179': 0,
#  '185 education;school;id;anonymized feature 245': 0,
#  '185 education;school;id;anonymized feature 860': 0,
#  '185 languages;id;anonymized feature 102': 0,
#  '185 location;id;anonymized feature 176': 0,
#  '185 work;location;id;anonymized feature 137': 0,
#  '186 education;school;id;anonymized feature 515': 0,
#  '186 education;school;id;anonymized feature 861': 0,
#  '186 last_name;anonymized feature 1103': 0,
#  '186 location;id;anonymized feature 179': 0,
#  '186 work;location;id;anonymized feature 180': 0,
#  '187 education;school;id;anonymized feature 246': 0,
#  '187 education;school;id;anonymized feature 516': 0,
#  '187 last_name;anonymized feature 1104': 0,
#  '187 location;id;anonymized feature 616': 0,
#  '187 work;location;id;anonymized feature 138': 0,
#  '188 education;school;id;anonymized feature 517': 0,
#  '188 education;school;id;anonymized feature 862': 0,
#  '188 last_name;anonymized feature 1105': 0,
#  '188 location;id;anonymized feature 297': 0,
#  '188 work;position;id;anonymized feature 181': 0,
#  '189 education;school;id;anonymized feature 246': 0,
#  '189 education;school;id;anonymized feature 863': 0,
#  '189 last_name;anonymized feature 1106': 0,
#  '189 location;id;anonymized feature 1252': 0,
#  '189 work;position;id;anonymized feature 182': 0,
#  '19 birthday;anonymized feature 739': 0,
#  '19 education;concentration;id;anonymized feature 19': 0,
#  '19 education;concentration;id;anonymized feature 217': 0,
#  '19 education;concentration;id;anonymized feature 384': 0,
#  '19 education;concentration;id;anonymized feature 388': 0,
#  '19 education;concentration;id;anonymized feature 392': 0,
#  '19 education;degree;id;anonymized feature 222': 0,
#  '19 education;school;id;anonymized feature 348': 0,
#  '19 education;year;id;anonymized feature 61': 0,
#  '19 gender;anonymized feature 77': 0,
#  '190 education;school;id;anonymized feature 518': 0,
#  '190 education;school;id;anonymized feature 864': 0,
#  '190 last_name;anonymized feature 1107': 0,
#  '190 location;id;anonymized feature 1223': 0,
#  '190 work;position;id;anonymized feature 183': 0,
#  '191 education;school;id;anonymized feature 247': 0,
#  '191 education;school;id;anonymized feature 865': 0,
#  '191 last_name;anonymized feature 268': 0,
#  '191 location;id;anonymized feature 619': 0,
#  '191 work;position;id;anonymized feature 184': 0,
#  '192 education;school;id;anonymized feature 519': 0,
#  '192 education;school;id;anonymized feature 866': 0,
#  '192 last_name;anonymized feature 1108': 0,
#  '192 location;id;anonymized feature 138': 0,
#  '192 work;position;id;anonymized feature 185': 0,
#  '193 education;school;id;anonymized feature 520': 0,
#  '193 education;school;id;anonymized feature 867': 0,
#  '193 last_name;anonymized feature 1109': 0,
#  '193 name;anonymized feature 1253': 0,
#  '193 work;position;id;anonymized feature 186': 0,
#  '194 education;school;id;anonymized feature 521': 0,
#  '194 education;school;id;anonymized feature 868': 0,
#  '194 last_name;anonymized feature 1110': 0,
#  '194 work;employer;id;anonymized feature 140': 0,
#  '194 work;position;id;anonymized feature 187': 0,
#  '195 education;school;id;anonymized feature 248': 0,
#  '195 education;school;id;anonymized feature 50': 0,
#  '195 last_name;anonymized feature 1111': 0,
#  '195 work;employer;id;anonymized feature 1156': 0,
#  '195 work;position;id;anonymized feature 188': 0,
#  '196 education;school;id;anonymized feature 522': 0,
#  '196 education;school;id;anonymized feature 523': 0,
#  '196 last_name;anonymized feature 1112': 0,
#  '196 work;employer;id;anonymized feature 1254': 0,
#  '196 work;position;id;anonymized feature 189': 0,
#  '197 education;school;id;anonymized feature 523': 0,
#  '197 education;school;id;anonymized feature 869': 0,
#  '197 last_name;anonymized feature 581': 0,
#  '197 work;employer;id;anonymized feature 1255': 0,
#  '197 work;position;id;anonymized feature 190': 0,
#  '198 education;school;id;anonymized feature 249': 0,
#  '198 education;school;id;anonymized feature 524': 0,
#  '198 last_name;anonymized feature 1113': 0,
#  '198 work;employer;id;anonymized feature 1256': 0,
#  '198 work;position;id;anonymized feature 191': 0,
#  '199 education;school;id;anonymized feature 318': 0,
#  '199 education;school;id;anonymized feature 870': 0,
#  '199 last_name;anonymized feature 1114': 0,
#  '199 work;employer;id;anonymized feature 1257': 0,
#  '199 work;position;id;anonymized feature 192': 0,
#  '2 birthday;anonymized feature 0': 0,
#  '2 birthday;anonymized feature 1': 0,
#  '2 birthday;anonymized feature 2': 0,
#  '2 birthday;anonymized feature 208': 0,
#  '2 birthday;anonymized feature 210': 0,
#  '2 birthday;anonymized feature 3': 0,
#  '2 birthday;anonymized feature 731': 0,
#  '2 education;classes;id;anonymized feature 335': 0,
#  '2 education;degree;id;anonymized feature 22': 0,
#  '20 birthday;anonymized feature 740': 0,
#  '20 education;concentration;id;anonymized feature 213': 0,
#  '20 education;concentration;id;anonymized feature 215': 0,
#  '20 education;concentration;id;anonymized feature 218': 0,
#  '20 education;concentration;id;anonymized feature 392': 0,
#  '20 education;degree;id;anonymized feature 20': 0,
#  '20 education;degree;id;anonymized feature 223': 0,
#  '20 education;school;id;anonymized feature 349': 0,
#  '20 education;year;id;anonymized feature 64': 0,
#  '20 gender;anonymized feature 78': 0,
#  '200 education;school;id;anonymized feature 249': 0,
#  '200 education;school;id;anonymized feature 871': 0,
#  '200 last_name;anonymized feature 1115': 0,
#  '200 work;employer;id;anonymized feature 1258': 0,
#  '200 work;position;id;anonymized feature 193': 0,
#  '201 education;school;id;anonymized feature 525': 0,
#  '201 education;school;id;anonymized feature 872': 0,
#  '201 last_name;anonymized feature 1116': 0,
#  '201 work;employer;id;anonymized feature 150': 0,
#  '201 work;start_date;anonymized feature 157': 0,
#  '202 education;school;id;anonymized feature 319': 0,
#  '202 education;school;id;anonymized feature 533': 0,
#  '202 last_name;anonymized feature 1117': 0,
#  '202 work;employer;id;anonymized feature 151': 0,
#  '202 work;start_date;anonymized feature 194': 0,
#  '203 education;school;id;anonymized feature 526': 0,
#  '203 education;school;id;anonymized feature 873': 0,
#  '203 last_name;anonymized feature 110': 0,
#  '203 work;employer;id;anonymized feature 1259': 0,
#  '203 work;start_date;anonymized feature 195': 0,
#  '204 education;school;id;anonymized feature 320': 0,
#  '204 education;school;id;anonymized feature 874': 0,
#  '204 last_name;anonymized feature 1118': 0,
#  '204 work;employer;id;anonymized feature 667': 0,
#  '204 work;start_date;anonymized feature 158': 0,
#  '205 education;school;id;anonymized feature 527': 0,
#  '205 education;school;id;anonymized feature 875': 0,
#  '205 last_name;anonymized feature 1119': 0,
#  '205 work;employer;id;anonymized feature 52': 0,
#  '205 work;start_date;anonymized feature 196': 0,
#  '206 education;school;id;anonymized feature 528': 0,
#  '206 education;school;id;anonymized feature 535': 0,
#  '206 last_name;anonymized feature 1120': 0,
#  '206 work;employer;id;anonymized feature 154': 0,
#  '206 work;start_date;anonymized feature 160': 0,
#  '207 education;school;id;anonymized feature 529': 0,
#  '207 education;school;id;anonymized feature 876': 0,
#  '207 last_name;anonymized feature 112': 0,
#  '207 work;employer;id;anonymized feature 537': 0,
#  '207 work;start_date;anonymized feature 197': 0,
#  '208 education;school;id;anonymized feature 530': 0,
#  '208 education;school;id;anonymized feature 877': 0,
#  '208 last_name;anonymized feature 1121': 0,
#  '208 work;employer;id;anonymized feature 1210': 0,
#  '208 work;start_date;anonymized feature 162': 0,
#  '209 education;school;id;anonymized feature 322': 0,
#  '209 education;school;id;anonymized feature 531': 0,
#  '209 last_name;anonymized feature 1122': 0,
#  '209 work;end_date;anonymized feature 157': 0,
#  '209 work;start_date;anonymized feature 198': 0,
#  '21 birthday;anonymized feature 741': 0,
#  '21 education;concentration;id;anonymized feature 1175': 0,
#  '21 education;concentration;id;anonymized feature 215': 0,
#  '21 education;concentration;id;anonymized feature 219': 0,
#  '21 education;concentration;id;anonymized feature 385': 0,
#  '21 education;degree;id;anonymized feature 21': 0,
#  '21 education;school;id;anonymized feature 314': 0,
#  '21 education;type;anonymized feature 53': 0,
#  '21 education;year;id;anonymized feature 71': 0,
#  '21 hometown;id;anonymized feature 1275': 0,
#  '210 education;school;id;anonymized feature 532': 0,
#  '210 education;school;id;anonymized feature 878': 0,
#  '210 last_name;anonymized feature 1123': 0,
#  '210 work;end_date;anonymized feature 672': 0,
#  '210 work;start_date;anonymized feature 164': 0,
#  '211 education;school;id;anonymized feature 250': 0,
#  '211 education;school;id;anonymized feature 52': 0,
#  '211 last_name;anonymized feature 1124': 0,
#  '211 work;end_date;anonymized feature 718': 0,
#  '211 work;start_date;anonymized feature 199': 0,
#  '212 education;school;id;anonymized feature 533': 0,
#  '212 education;school;id;anonymized feature 879': 0,
#  '212 last_name;anonymized feature 1125': 0,
#  '212 work;end_date;anonymized feature 1260': 0,
#  '212 work;start_date;anonymized feature 165': 0,
#  '213 education;school;id;anonymized feature 251': 0,
#  '213 education;school;id;anonymized feature 880': 0,
#  '213 last_name;anonymized feature 1126': 0,
#  '213 work;end_date;anonymized feature 676': 0,
#  '213 work;start_date;anonymized feature 166': 0,
#  '214 education;school;id;anonymized feature 534': 0,
#  '214 education;school;id;anonymized feature 537': 0,
#  '214 last_name;anonymized feature 1127': 0,
#  '214 work;end_date;anonymized feature 720': 0,
#  '214 work;start_date;anonymized feature 200': 0,
#  '215 education;school;id;anonymized feature 535': 0,
#  '215 education;school;id;anonymized feature 881': 0,
#  '215 last_name;anonymized feature 1128': 0,
#  '215 work;end_date;anonymized feature 722': 0,
#  '215 work;start_date;anonymized feature 201': 0,
#  '216 education;school;id;anonymized feature 536': 0,
#  '216 education;school;id;anonymized feature 538': 0,
#  '216 last_name;anonymized feature 1129': 0,
#  '216 work;end_date;anonymized feature 976': 0,
#  '216 work;start_date;anonymized feature 168': 0,
#  '217 education;school;id;anonymized feature 52': 0,
#  '217 education;school;id;anonymized feature 882': 0,
#  '217 last_name;anonymized feature 1130': 0,
#  '217 work;end_date;anonymized feature 723': 0,
#  '217 work;start_date;anonymized feature 202': 0,
#  '218 education;school;id;anonymized feature 537': 0,
#  '218 education;type;anonymized feature 53': 0,
#  '218 last_name;anonymized feature 1131': 0,
#  '218 work;end_date;anonymized feature 198': 0,
#  '218 work;start_date;anonymized feature 169': 0,
#  '219 education;school;id;anonymized feature 538': 0,
#  '219 education;type;anonymized feature 54': 0,
#  '219 last_name;anonymized feature 1132': 0,
#  '219 work;end_date;anonymized feature 199': 0,
#  '219 work;start_date;anonymized feature 170': 0,
#  '22 education;classes;id;anonymized feature 742': 0,
#  '22 education;concentration;id;anonymized feature 1176': 0,
#  '22 education;concentration;id;anonymized feature 386': 0,
#  '22 education;concentration;id;anonymized feature 394': 0,
#  '22 education;degree;id;anonymized feature 20': 0,
#  '22 education;degree;id;anonymized feature 22': 0,
#  '22 education;school;id;anonymized feature 226': 0,
#  '22 education;type;anonymized feature 54': 0,
#  '22 education;year;id;anonymized feature 259': 0,
#  '22 languages;id;anonymized feature 90': 0,
#  '220 education;type;anonymized feature 53': 0,
#  '220 education;type;anonymized feature 55': 0,
#  '220 last_name;anonymized feature 1133': 0,
#  '220 work;end_date;anonymized feature 165': 0,
#  '220 work;start_date;anonymized feature 171': 0,
#  '221 education;type;anonymized feature 54': 0,
#  '221 education;with;id;anonymized feature 883': 0,
#  '221 last_name;anonymized feature 1134': 0,
#  '221 work;end_date;anonymized feature 166': 0,
#  '221 work;start_date;anonymized feature 203': 0,
#  '222 education;type;anonymized feature 55': 0,
#  '222 education;with;id;anonymized feature 884': 0,
#  '222 last_name;anonymized feature 1135': 0,
#  '222 work;end_date;anonymized feature 200': 0,
#  '222 work;start_date;anonymized feature 204': 0,
#  '223 education;with;id;anonymized feature 539': 0,
#  '223 education;with;id;anonymized feature 885': 0,
#  '223 last_name;anonymized feature 1136': 0,
#  '223 work;end_date;anonymized feature 201': 0,
#  '223 work;with;id;anonymized feature 205': 0,
#  '224 education;with;id;anonymized feature 540': 0,
#  '224 education;with;id;anonymized feature 886': 0,
#  '224 last_name;anonymized feature 1137': 0,
#  '224 work;end_date;anonymized feature 169': 0,
#  '225 education;with;id;anonymized feature 541': 0,
#  '225 education;with;id;anonymized feature 887': 0,
#  '225 last_name;anonymized feature 1138': 0,
#  '225 work;location;id;anonymized feature 128': 0,
#  '226 education;year;id;anonymized feature 542': 0,
#  '226 education;year;id;anonymized feature 543': 0,
#  '226 last_name;anonymized feature 1139': 0,
#  '226 work;location;id;anonymized feature 129': 0,
#  '227 education;year;id;anonymized feature 543': 0,
#  '227 education;year;id;anonymized feature 58': 0,
#  '227 locale;anonymized feature 126': 0,
#  '227 work;location;id;anonymized feature 296': 0,
#  '228 education;year;id;anonymized feature 58': 0,
#  '228 education;year;id;anonymized feature 888': 0,
#  '228 locale;anonymized feature 127': 0,
#  '228 work;location;id;anonymized feature 174': 0,
#  '229 education;year;id;anonymized feature 59': 0,
#  '229 locale;anonymized feature 1140': 0,
#  '229 work;location;id;anonymized feature 133': 0,
#  '23 education;classes;id;anonymized feature 743': 0,
#  '23 education;concentration;id;anonymized feature 14': 0,
#  '23 education;concentration;id;anonymized feature 395': 0,
#  '23 education;degree;id;anonymized feature 21': 0,
#  '23 education;degree;id;anonymized feature 23': 0,
#  '23 education;school;id;anonymized feature 228': 0,
#  '23 education;type;anonymized feature 55': 0,
#  '23 education;year;id;anonymized feature 72': 0,
#  '23 languages;id;anonymized feature 92': 0,
#  '230 education;year;id;anonymized feature 544': 0,
#  '230 locale;anonymized feature 1141': 0,
#  '230 work;location;id;anonymized feature 176': 0,
#  '231 education;year;id;anonymized feature 254': 0,
#  '231 education;year;id;anonymized feature 255': 0,
#  '231 location;id;anonymized feature 1142': 0,
#  '231 work;location;id;anonymized feature 177': 0,
#  '232 education;year;id;anonymized feature 255': 0,
#  '232 education;year;id;anonymized feature 889': 0,
#  '232 location;id;anonymized feature 128': 0,
#  '232 work;location;id;anonymized feature 1220': 0,
#  '233 education;year;id;anonymized feature 60': 0,
#  '233 location;id;anonymized feature 1143': 0,
#  '233 work;location;id;anonymized feature 179': 0,
#  '234 education;year;id;anonymized feature 61': 0,
#  '234 education;year;id;anonymized feature 890': 0,
#  '234 location;id;anonymized feature 612': 0,
#  '234 work;location;id;anonymized feature 283': 0,
#  '235 education;year;id;anonymized feature 61': 0,
#  '235 education;year;id;anonymized feature 62': 0,
#  '235 location;id;anonymized feature 1144': 0,
#  '235 work;location;id;anonymized feature 284': 0,
#  '236 education;year;id;anonymized feature 62': 0,
#  '236 education;year;id;anonymized feature 63': 0,
#  '236 location;id;anonymized feature 1145': 0,
#  '236 work;location;id;anonymized feature 619': 0,
#  '237 education;year;id;anonymized feature 63': 0,
#  '237 education;year;id;anonymized feature 64': 0,
#  '237 location;id;anonymized feature 935': 0,
#  '237 work;location;id;anonymized feature 138': 0,
#  '238 education;year;id;anonymized feature 64': 0,
#  '238 education;year;id;anonymized feature 65': 0,
#  '238 location;id;anonymized feature 1146': 0,
#  '238 work;position;id;anonymized feature 1261': 0,
#  '239 education;year;id;anonymized feature 65': 0,
#  '239 education;year;id;anonymized feature 66': 0,
#  '239 location;id;anonymized feature 1147': 0,
#  '239 work;position;id;anonymized feature 1262': 0,
#  '24 education;classes;id;anonymized feature 744': 0,
#  '24 education;concentration;id;anonymized feature 1010': 0,
#  '24 education;concentration;id;anonymized feature 387': 0,
#  '24 education;concentration;id;anonymized feature 397': 0,
#  '24 education;degree;id;anonymized feature 220': 0,
#  '24 education;school;id;anonymized feature 229': 0,
#  '24 education;school;id;anonymized feature 24': 0,
#  '24 education;with;id;anonymized feature 350': 0,
#  '24 first_name;anonymized feature 355': 0,
#  '24 last_name;anonymized feature 1276': 0,
#  '240 education;year;id;anonymized feature 66': 0,
#  '240 education;year;id;anonymized feature 67': 0,
#  '240 location;id;anonymized feature 281': 0,
#  '240 work;position;id;anonymized feature 1263': 0,
#  '241 education;year;id;anonymized feature 67': 0,
#  '241 education;year;id;anonymized feature 68': 0,
#  '241 location;id;anonymized feature 176': 0,
#  '241 work;position;id;anonymized feature 183': 0,
#  '242 education;year;id;anonymized feature 68': 0,
#  '242 education;year;id;anonymized feature 69': 0,
#  '242 location;id;anonymized feature 134': 0,
#  '242 work;position;id;anonymized feature 691': 0,
#  '243 education;year;id;anonymized feature 257': 0,
#  '243 education;year;id;anonymized feature 69': 0,
#  '243 location;id;anonymized feature 1148': 0,
#  '243 work;position;id;anonymized feature 1264': 0,
#  '244 education;year;id;anonymized feature 258': 0,
#  '244 education;year;id;anonymized feature 70': 0,
#  '244 location;id;anonymized feature 685': 0,
#  '244 work;position;id;anonymized feature 299': 0,
#  '245 education;year;id;anonymized feature 71': 0,
#  '245 location;id;anonymized feature 940': 0,
#  '245 work;position;id;anonymized feature 1265': 0,
#  '246 education;year;id;anonymized feature 259': 0,
#  '246 location;id;anonymized feature 1149': 0,
#  '246 work;position;id;anonymized feature 1266': 0,
#  '247 education;year;id;anonymized feature 72': 0,
#  '247 location;id;anonymized feature 1150': 0,
#  '247 work;start_date;anonymized feature 157': 0,
#  '248 first_name;anonymized feature 545': 0,
#  '248 first_name;anonymized feature 891': 0,
#  '248 location;id;anonymized feature 179': 0,
#  '248 work;start_date;anonymized feature 1267': 0,
#  '249 first_name;anonymized feature 546': 0,
#  '249 first_name;anonymized feature 892': 0,
#  '249 location;id;anonymized feature 1151': 0,
#  '249 work;start_date;anonymized feature 713': 0,
#  '25 education;classes;id;anonymized feature 745': 0,
#  '25 education;concentration;id;anonymized feature 216': 0,
#  '25 education;concentration;id;anonymized feature 388': 0,
#  '25 education;concentration;id;anonymized feature 398': 0,
#  '25 education;degree;id;anonymized feature 22': 0,
#  '25 education;school;id;anonymized feature 230': 0,
#  '25 education;school;id;anonymized feature 25': 0,
#  '25 education;with;id;anonymized feature 351': 0,
#  '25 first_name;anonymized feature 356': 0,
#  '25 last_name;anonymized feature 1277': 0,
#  '250 first_name;anonymized feature 547': 0,
#  '250 first_name;anonymized feature 893': 0,
#  '250 location;id;anonymized feature 1095': 0,
#  '250 work;start_date;anonymized feature 1268': 0,
#  '251 first_name;anonymized feature 548': 0,
#  '251 first_name;anonymized feature 894': 0,
#  '251 location;id;anonymized feature 617': 0,
#  '251 work;start_date;anonymized feature 194': 0,
#  '252 first_name;anonymized feature 549': 0,
#  '252 first_name;anonymized feature 895': 0,
#  '252 location;id;anonymized feature 1152': 0,
#  '252 work;start_date;anonymized feature 1269': 0,
#  '253 first_name;anonymized feature 550': 0,
#  '253 first_name;anonymized feature 896': 0,
#  '253 location;id;anonymized feature 284': 0,
#  '253 work;start_date;anonymized feature 375': 0,
#  '254 first_name;anonymized feature 325': 0,
#  '254 first_name;anonymized feature 897': 0,
#  '254 location;id;anonymized feature 1153': 0,
#  '254 work;start_date;anonymized feature 675': 0,
#  '255 first_name;anonymized feature 551': 0,
#  '255 first_name;anonymized feature 898': 0,
#  '255 location;id;anonymized feature 138': 0,
#  '255 work;start_date;anonymized feature 310': 0,
#  '256 first_name;anonymized feature 110': 0,
#  '256 first_name;anonymized feature 899': 0,
#  '256 religion;anonymized feature 1154': 0,
#  '256 work;start_date;anonymized feature 158': 0,
#  '257 first_name;anonymized feature 357': 0,
#  '257 first_name;anonymized feature 900': 0,
#  '257 work;employer;id;anonymized feature 1155': 0,
#  '257 work;start_date;anonymized feature 162': 0,
#  '258 first_name;anonymized feature 552': 0,
#  '258 first_name;anonymized feature 901': 0,
#  '258 work;employer;id;anonymized feature 140': 0,
#  ...}
