# %%
import torch
import torch.nn.functional as F
import torchmetrics
from torch_geometric.nn import GATConv
import matplotlib.pyplot as plt
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
import itertools

# %%
# ucitavanje grafa
with open('../preprocessing/graph.pkl', 'rb') as f:
    G = pickle.load(f)

# %%
from torch_geometric.utils import from_networkx
data = from_networkx(G)

# %%
# podela cvorova na trening, validacioni i test skup
nodes = list(G.nodes)
train_nodes, test_nodes = train_test_split(nodes, test_size=0.2, random_state=42)
train_nodes, val_nodes = train_test_split(train_nodes, test_size=0.2, random_state=42)

# %%
# kreiranje maske za skupove
train_mask = torch.tensor([True if node in train_nodes else False for node in range(len(G.nodes))])
val_mask = torch.tensor([True if node in val_nodes else False for node in range(len(G.nodes))])
test_mask = torch.tensor([True if node in test_nodes else False for node in range(len(G.nodes))])

# %%
# atributi
node_features = [list(G.nodes[node].values())[:-1] for node in G.nodes]
node_features = torch.tensor(node_features, dtype=torch.float)

# ciljne promenljive
labels = np.array([G.nodes[node]['target'] for node in G.nodes])
labels = torch.tensor(labels, dtype=torch.float)

# dodajemo i labelu koja ce da oznacava da cvor ne pripada nijednoj ego mrezi 
# -> kako bismo mogli da dodelimo odgovarajucu tezinu zbog nebalansiranosti klasa :)
no_class_nodes = (labels.sum(dim=1) == 0).float()
dummy_class = no_class_nodes.unsqueeze(1)
labels = torch.cat([labels, dummy_class], dim=1)


data.x = node_features
data.y = labels
data.train_mask = train_mask
data.val_mask = val_mask
data.test_mask = test_mask

# %%
class GAT(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, dropout_rate, num_heads=4):
        super(GAT, self).__init__()
        self.gat1 = GATConv(in_channels, hidden_channels, heads=num_heads, concat=True)
        self.dropout = torch.nn.Dropout(dropout_rate)
        self.gat2 = GATConv(hidden_channels * num_heads, out_channels, heads=1, concat=False)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.gat1(x, edge_index)
        x = F.elu(x)
        x = self.dropout(x)
        x = self.gat2(x, edge_index)
        return x

# %%
# Hiperparametri
hyperparameters = {
    'hidden_channels': [32, 64],
    'dropout_rate': [0.2, 0.5],
    'num_heads': [2, 4, 8],
    'num_epochs': [30, 60]
}
learning_rate = 0.01
weight_decay = 5e-4
# early_stopping_threshold = 20  # Broj epoha pre zaustavljanja

# %%
# metrike
device = 'cuda' if torch.cuda.is_available() else 'cpu'
precision = torchmetrics.Precision(num_labels=labels.shape[1], average='macro', task='multilabel').to(device)
recall = torchmetrics.Recall(num_labels=labels.shape[1], average='macro', task='multilabel').to(device)
f1 = torchmetrics.F1Score(num_labels=labels.shape[1], average='macro', task='multilabel').to(device)

# %%
from sklearn.metrics import multilabel_confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

ego_to_index_df = pd.read_csv("../preprocessing/ego_to_index.csv", index_col=0)
ego_to_index = ego_to_index_df.to_dict(orient='index')
ego_to_index = {int(ego_id): int(index['index']) for ego_id, index in ego_to_index.items()}

# Funkcija za prikaz matrice konfuzije
def plot_confusion_matrix(y_true, y_pred, num_classes):
    conf_matrix = multilabel_confusion_matrix(y_true, y_pred)
    
    # Prikaz za svaku klasu
    for i in range(num_classes):
        plt.figure(figsize=(5, 4))
        sns.heatmap(conf_matrix[i], annot=True, fmt='d', cmap='Blues')
        if i == 10:
            plt.title(f'Matrica konfuzije za čvorove koji ne pripadaju nijednoj ego mreži')
        else:
            plt.title(f'Matrica konfuzije za ego mrežu čvora {[key for key, value in ego_to_index.items() if value == i]}')
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.show()

# %%
train_labels = labels[data.train_mask]  
nodes_in_ego_train = train_labels.sum(dim=0)

total_train_nodes_num = train_labels.shape[0]
class_weights = total_train_nodes_num / (nodes_in_ego_train + 1e-6)  

print(f'Nodes in ego (train only): {nodes_in_ego_train}')
print(f'Class weights: {class_weights}')
# Out:
# Nodes in ego (train only): tensor([168., 290., 133.,  94., 112.,  33., 498., 474.,  68.,  36., 736.])
# Class weights: tensor([15.3810,  8.9103, 19.4286, 27.4894, 23.0714, 78.3030,  5.1888,  5.4515,
#         38.0000, 71.7778,  3.5109])

# %%
def train():
    model.train()
    optimizer.zero_grad()
    
    pred_train = model(data)[data.train_mask].to(device)
    loss = criterion(pred_train, data.y[data.train_mask].float().to(device))
    loss.backward()
    optimizer.step()
    
    preds_train = (torch.sigmoid(pred_train) > 0.5).float()
    acc_train = (preds_train == data.y[data.train_mask].to(device)).float().mean()
    precision_train = precision(pred_train.to(device), data.y[data.train_mask].to(device))
    recall_train = recall(pred_train.to(device), data.y[data.train_mask].to(device))
    f1_train = f1(pred_train.to(device), data.y[data.train_mask].to(device))
    
    return loss, acc_train.item(), precision_train.item(), recall_train.item(), f1_train.item()

# %%
def evaluate(mask):
    model.eval()
    with torch.no_grad():
        pred_val = model(data)[mask].to(device)
        loss_val = criterion(pred_val, data.y[mask].float().to(device))
        
        preds_val = (torch.sigmoid(pred_val) > 0.5).float()
        acc_val = (preds_val == data.y[mask].to(device)).float().mean()
        precision_val = precision(pred_val.to(device), data.y[mask].to(device))
        recall_val = recall(pred_val.to(device), data.y[mask].to(device))
        f1_val = f1(pred_val.to(device), data.y[mask].to(device))

        if torch.equal(mask, data.test_mask):
            # Vizualizacija matrice konfuzije na test skupu
            plot_confusion_matrix(data.y[data.test_mask].to(device), preds_val.to(device), labels.shape[1])
        
        
    return loss_val, acc_val.item(), precision_val.item(), recall_val.item(), f1_val.item()

# %%
# treniranje i podešavanje hiperparametara
best_params = None
best_loss = float('inf')

# kreiranje svih kombinacije hiperparametara
param_combinations = list(itertools.product(
    hyperparameters['hidden_channels'],
    hyperparameters['dropout_rate'],
    hyperparameters['num_heads'],
    hyperparameters['num_epochs']
))

for params in param_combinations:
    hidden_channels, dropout_rate, num_heads, num_epochs = params
    print(f'Testing parameters: {params}')

    # Inicijalizacija modela, optimizatora i kriterijuma
    model = None
    model = GAT(in_channels=node_features.shape[1], hidden_channels=hidden_channels, out_channels=labels.shape[1], dropout_rate=dropout_rate, num_heads=num_heads).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    criterion = torch.nn.BCEWithLogitsLoss(pos_weight=class_weights.to(device))

    for epoch in range(num_epochs):
        loss_train, acc_train, precision_train, recall_train, f1_train = train()
        
        if epoch % 10 == 0:
            print(f'[Train] Epoch: {epoch}, Loss: {loss_train:.4f}, Accuracy: {acc_train:.4f}, Precision: {precision_train:.4f}, Recall: {recall_train:.4f}, F1: {f1_train:.4f}')
        
        if epoch == num_epochs-1:
            loss_val, acc_val, precision_val, recall_val, f1_val = evaluate(data.val_mask)
            print(f'[Validate] Loss: {loss_val:.4f}, Accuracy: {acc_val:.4f}, Precision: {precision_val:.4f}, Recall: {recall_val:.4f}, F1: {f1_val:.4f}')
            if loss_val < best_loss:
                best_loss = loss_val
                best_params = params

print(f'Best parameters: {best_params}, with loss: {best_loss:.4f}')
# Out:
# Testing parameters: (32, 0.2, 2, 30)
# [Train] Epoch: 0, Loss: 1.3238, Accuracy: 0.4230, Precision: 0.0884, Recall: 0.5906, F1: 0.1402
# [Train] Epoch: 10, Loss: 0.2716, Accuracy: 0.9371, Precision: 0.6154, Recall: 0.9753, F1: 0.7202
# [Train] Epoch: 20, Loss: 0.2005, Accuracy: 0.9501, Precision: 0.6745, Recall: 0.9758, F1: 0.7621
# [Validate] Loss: 0.2200, Accuracy: 0.9503, Precision: 0.7051, Recall: 0.9682, F1: 0.7799
# Testing parameters: (32, 0.2, 2, 60)
# [Train] Epoch: 0, Loss: 1.3245, Accuracy: 0.4234, Precision: 0.1107, Recall: 0.4360, F1: 0.1459
# [Train] Epoch: 10, Loss: 0.2929, Accuracy: 0.9437, Precision: 0.6286, Recall: 0.9548, F1: 0.7236
# [Train] Epoch: 20, Loss: 0.2016, Accuracy: 0.9489, Precision: 0.6693, Recall: 0.9766, F1: 0.7592
# [Train] Epoch: 30, Loss: 0.1899, Accuracy: 0.9538, Precision: 0.7132, Recall: 0.9803, F1: 0.8008
# [Train] Epoch: 40, Loss: 0.1829, Accuracy: 0.9528, Precision: 0.6887, Recall: 0.9832, F1: 0.7815
# [Train] Epoch: 50, Loss: 0.1727, Accuracy: 0.9541, Precision: 0.7163, Recall: 0.9835, F1: 0.8038
# [Validate] Loss: 0.1994, Accuracy: 0.9531, Precision: 0.7178, Recall: 0.9763, F1: 0.7977
# Testing parameters: (32, 0.2, 4, 30)
# [Train] Epoch: 0, Loss: 1.3103, Accuracy: 0.5138, Precision: 0.1128, Recall: 0.6195, F1: 0.1634
# [Train] Epoch: 10, Loss: 0.2199, Accuracy: 0.9441, Precision: 0.6440, Recall: 0.9799, F1: 0.7396
# [Train] Epoch: 20, Loss: 0.1816, Accuracy: 0.9502, Precision: 0.6848, Recall: 0.9831, F1: 0.7734
# [Validate] Loss: 0.2096, Accuracy: 0.9496, Precision: 0.6842, Recall: 0.9672, F1: 0.7666
# Testing parameters: (32, 0.2, 4, 60)
# [Train] Epoch: 0, Loss: 1.3083, Accuracy: 0.4136, Precision: 0.0895, Recall: 0.6813, F1: 0.1472
# [Train] Epoch: 10, Loss: 0.2274, Accuracy: 0.9377, Precision: 0.6279, Recall: 0.9811, F1: 0.7277
# [Train] Epoch: 20, Loss: 0.1827, Accuracy: 0.9530, Precision: 0.6911, Recall: 0.9810, F1: 0.7766
# [Train] Epoch: 30, Loss: 0.1720, Accuracy: 0.9531, Precision: 0.6934, Recall: 0.9839, F1: 0.7813
# [Train] Epoch: 40, Loss: 0.1669, Accuracy: 0.9572, Precision: 0.7266, Recall: 0.9827, F1: 0.8120
# [Train] Epoch: 50, Loss: 0.1603, Accuracy: 0.9587, Precision: 0.7334, Recall: 0.9842, F1: 0.8173
# [Validate] Loss: 0.1953, Accuracy: 0.9598, Precision: 0.7336, Recall: 0.9702, F1: 0.8089
# Testing parameters: (32, 0.2, 8, 30)
# [Train] Epoch: 0, Loss: 1.3155, Accuracy: 0.5436, Precision: 0.0939, Recall: 0.4780, F1: 0.1452
# [Train] Epoch: 10, Loss: 0.2024, Accuracy: 0.9437, Precision: 0.6588, Recall: 0.9850, F1: 0.7491
# [Train] Epoch: 20, Loss: 0.1767, Accuracy: 0.9537, Precision: 0.6883, Recall: 0.9775, F1: 0.7724
# [Validate] Loss: 0.2065, Accuracy: 0.9490, Precision: 0.6815, Recall: 0.9730, F1: 0.7647
# Testing parameters: (32, 0.2, 8, 60)
# [Train] Epoch: 0, Loss: 1.3374, Accuracy: 0.4889, Precision: 0.0613, Recall: 0.3637, F1: 0.0936
# [Train] Epoch: 10, Loss: 0.2093, Accuracy: 0.9484, Precision: 0.6681, Recall: 0.9802, F1: 0.7575
# [Train] Epoch: 20, Loss: 0.1807, Accuracy: 0.9527, Precision: 0.6890, Recall: 0.9806, F1: 0.7746
# [Train] Epoch: 30, Loss: 0.1747, Accuracy: 0.9534, Precision: 0.6870, Recall: 0.9828, F1: 0.7762
# [Train] Epoch: 40, Loss: 0.1716, Accuracy: 0.9547, Precision: 0.6926, Recall: 0.9821, F1: 0.7797
# [Train] Epoch: 50, Loss: 0.1676, Accuracy: 0.9551, Precision: 0.7022, Recall: 0.9842, F1: 0.7914
# [Validate] Loss: 0.1961, Accuracy: 0.9542, Precision: 0.7023, Recall: 0.9734, F1: 0.7816
# Testing parameters: (32, 0.5, 2, 30)
# [Train] Epoch: 0, Loss: 1.3378, Accuracy: 0.4821, Precision: 0.1157, Recall: 0.5012, F1: 0.1709
# [Train] Epoch: 10, Loss: 0.2845, Accuracy: 0.9332, Precision: 0.5826, Recall: 0.9709, F1: 0.6974
# [Train] Epoch: 20, Loss: 0.2187, Accuracy: 0.9442, Precision: 0.6585, Recall: 0.9787, F1: 0.7489
# [Validate] Loss: 0.2055, Accuracy: 0.9470, Precision: 0.6738, Recall: 0.9784, F1: 0.7572
# Testing parameters: (32, 0.5, 2, 60)
# [Train] Epoch: 0, Loss: 1.3216, Accuracy: 0.5947, Precision: 0.1432, Recall: 0.4391, F1: 0.1900
# [Train] Epoch: 10, Loss: 0.2849, Accuracy: 0.9382, Precision: 0.5845, Recall: 0.9628, F1: 0.6964
# [Train] Epoch: 20, Loss: 0.2173, Accuracy: 0.9463, Precision: 0.6559, Recall: 0.9769, F1: 0.7484
# [Train] Epoch: 30, Loss: 0.1977, Accuracy: 0.9507, Precision: 0.6770, Recall: 0.9788, F1: 0.7672
# [Train] Epoch: 40, Loss: 0.1884, Accuracy: 0.9523, Precision: 0.6866, Recall: 0.9774, F1: 0.7739
# [Train] Epoch: 50, Loss: 0.1802, Accuracy: 0.9532, Precision: 0.6946, Recall: 0.9816, F1: 0.7805
# [Validate] Loss: 0.2378, Accuracy: 0.9526, Precision: 0.6964, Recall: 0.9699, F1: 0.7783
# Testing parameters: (32, 0.5, 4, 30)
# [Train] Epoch: 0, Loss: 1.3442, Accuracy: 0.3823, Precision: 0.0540, Recall: 0.3823, F1: 0.0850
# [Train] Epoch: 10, Loss: 0.2408, Accuracy: 0.9407, Precision: 0.6408, Recall: 0.9803, F1: 0.7362
# [Train] Epoch: 20, Loss: 0.1960, Accuracy: 0.9478, Precision: 0.6738, Recall: 0.9845, F1: 0.7634
# [Validate] Loss: 0.2035, Accuracy: 0.9493, Precision: 0.6774, Recall: 0.9756, F1: 0.7626
# Testing parameters: (32, 0.5, 4, 60)
# [Train] Epoch: 0, Loss: 1.3350, Accuracy: 0.4731, Precision: 0.0588, Recall: 0.3536, F1: 0.0790
# [Train] Epoch: 10, Loss: 0.2375, Accuracy: 0.9392, Precision: 0.6146, Recall: 0.9719, F1: 0.7158
# [Train] Epoch: 20, Loss: 0.1994, Accuracy: 0.9491, Precision: 0.6721, Recall: 0.9802, F1: 0.7626
# [Train] Epoch: 30, Loss: 0.1862, Accuracy: 0.9512, Precision: 0.6761, Recall: 0.9820, F1: 0.7672
# [Train] Epoch: 40, Loss: 0.1804, Accuracy: 0.9517, Precision: 0.6873, Recall: 0.9834, F1: 0.7747
# [Train] Epoch: 50, Loss: 0.1758, Accuracy: 0.9523, Precision: 0.6838, Recall: 0.9851, F1: 0.7736
# [Validate] Loss: 0.2596, Accuracy: 0.9512, Precision: 0.6970, Recall: 0.9721, F1: 0.7777
# Testing parameters: (32, 0.5, 8, 30)
# [Train] Epoch: 0, Loss: 1.3410, Accuracy: 0.4369, Precision: 0.0425, Recall: 0.3820, F1: 0.0670
# [Train] Epoch: 10, Loss: 0.2195, Accuracy: 0.9441, Precision: 0.6573, Recall: 0.9810, F1: 0.7470
# [Train] Epoch: 20, Loss: 0.1878, Accuracy: 0.9525, Precision: 0.6915, Recall: 0.9820, F1: 0.7774
# [Validate] Loss: 0.2211, Accuracy: 0.9497, Precision: 0.6838, Recall: 0.9700, F1: 0.7663
# Testing parameters: (32, 0.5, 8, 60)
# [Train] Epoch: 0, Loss: 1.3186, Accuracy: 0.5859, Precision: 0.0844, Recall: 0.3966, F1: 0.1221
# [Train] Epoch: 10, Loss: 0.2197, Accuracy: 0.9444, Precision: 0.6537, Recall: 0.9784, F1: 0.7463
# [Train] Epoch: 20, Loss: 0.1878, Accuracy: 0.9508, Precision: 0.7067, Recall: 0.9815, F1: 0.7939
# [Train] Epoch: 30, Loss: 0.1762, Accuracy: 0.9547, Precision: 0.7233, Recall: 0.9829, F1: 0.8080
# [Train] Epoch: 40, Loss: 0.1719, Accuracy: 0.9539, Precision: 0.7183, Recall: 0.9857, F1: 0.8061
# [Train] Epoch: 50, Loss: 0.1703, Accuracy: 0.9558, Precision: 0.7146, Recall: 0.9852, F1: 0.8028
# [Validate] Loss: 0.1933, Accuracy: 0.9538, Precision: 0.7095, Recall: 0.9805, F1: 0.7942
# Testing parameters: (64, 0.2, 2, 30)
# [Train] Epoch: 0, Loss: 1.3391, Accuracy: 0.4024, Precision: 0.0362, Recall: 0.2619, F1: 0.0549
# [Train] Epoch: 10, Loss: 0.2383, Accuracy: 0.9414, Precision: 0.6365, Recall: 0.9757, F1: 0.7303
# [Train] Epoch: 20, Loss: 0.1901, Accuracy: 0.9495, Precision: 0.6800, Recall: 0.9818, F1: 0.7673
# [Validate] Loss: 0.2107, Accuracy: 0.9490, Precision: 0.6764, Recall: 0.9788, F1: 0.7636
# Testing parameters: (64, 0.2, 2, 60)
# [Train] Epoch: 0, Loss: 1.3402, Accuracy: 0.4684, Precision: 0.0364, Recall: 0.2951, F1: 0.0587
# [Train] Epoch: 10, Loss: 0.2261, Accuracy: 0.9459, Precision: 0.6326, Recall: 0.9693, F1: 0.7251
# [Train] Epoch: 20, Loss: 0.1812, Accuracy: 0.9524, Precision: 0.6891, Recall: 0.9821, F1: 0.7742
# [Train] Epoch: 30, Loss: 0.1718, Accuracy: 0.9516, Precision: 0.6856, Recall: 0.9856, F1: 0.7736
# [Train] Epoch: 40, Loss: 0.1653, Accuracy: 0.9530, Precision: 0.6906, Recall: 0.9863, F1: 0.7792
# [Train] Epoch: 50, Loss: 0.1643, Accuracy: 0.9551, Precision: 0.6969, Recall: 0.9842, F1: 0.7835
# [Validate] Loss: 0.1997, Accuracy: 0.9578, Precision: 0.7093, Recall: 0.9723, F1: 0.7880
# Testing parameters: (64, 0.2, 4, 30)
# [Train] Epoch: 0, Loss: 1.3322, Accuracy: 0.5395, Precision: 0.0732, Recall: 0.3568, F1: 0.1077
# [Train] Epoch: 10, Loss: 0.2022, Accuracy: 0.9481, Precision: 0.6728, Recall: 0.9814, F1: 0.7613
# [Train] Epoch: 20, Loss: 0.1783, Accuracy: 0.9525, Precision: 0.6879, Recall: 0.9832, F1: 0.7758
# [Validate] Loss: 0.2087, Accuracy: 0.9534, Precision: 0.7268, Recall: 0.9709, F1: 0.8009
# Testing parameters: (64, 0.2, 4, 60)
# [Train] Epoch: 0, Loss: 1.3325, Accuracy: 0.4312, Precision: 0.0696, Recall: 0.5167, F1: 0.1095
# [Train] Epoch: 10, Loss: 0.2122, Accuracy: 0.9479, Precision: 0.6627, Recall: 0.9749, F1: 0.7519
# [Train] Epoch: 20, Loss: 0.1813, Accuracy: 0.9519, Precision: 0.6885, Recall: 0.9836, F1: 0.7761
# [Train] Epoch: 30, Loss: 0.1727, Accuracy: 0.9539, Precision: 0.6937, Recall: 0.9843, F1: 0.7809
# [Train] Epoch: 40, Loss: 0.1662, Accuracy: 0.9567, Precision: 0.7029, Recall: 0.9816, F1: 0.7873
# [Train] Epoch: 50, Loss: 0.1579, Accuracy: 0.9596, Precision: 0.7152, Recall: 0.9844, F1: 0.8017
# [Validate] Loss: 0.1986, Accuracy: 0.9597, Precision: 0.7454, Recall: 0.9736, F1: 0.8180
# Testing parameters: (64, 0.2, 8, 30)
# [Train] Epoch: 0, Loss: 1.3217, Accuracy: 0.4803, Precision: 0.0763, Recall: 0.4203, F1: 0.1162
# [Train] Epoch: 10, Loss: 0.1975, Accuracy: 0.9535, Precision: 0.6832, Recall: 0.9721, F1: 0.7681
# [Train] Epoch: 20, Loss: 0.1812, Accuracy: 0.9513, Precision: 0.6877, Recall: 0.9806, F1: 0.7742
# [Validate] Loss: 0.2002, Accuracy: 0.9508, Precision: 0.6862, Recall: 0.9717, F1: 0.7693
# Testing parameters: (64, 0.2, 8, 60)
# [Train] Epoch: 0, Loss: 1.3238, Accuracy: 0.5357, Precision: 0.0951, Recall: 0.4708, F1: 0.1467
# [Train] Epoch: 10, Loss: 0.1993, Accuracy: 0.9543, Precision: 0.6893, Recall: 0.9740, F1: 0.7750
# [Train] Epoch: 20, Loss: 0.1767, Accuracy: 0.9501, Precision: 0.6831, Recall: 0.9836, F1: 0.7716
# [Train] Epoch: 30, Loss: 0.1698, Accuracy: 0.9546, Precision: 0.6926, Recall: 0.9814, F1: 0.7783
# [Train] Epoch: 40, Loss: 0.1640, Accuracy: 0.9541, Precision: 0.6943, Recall: 0.9879, F1: 0.7808
# [Train] Epoch: 50, Loss: 0.1588, Accuracy: 0.9543, Precision: 0.6945, Recall: 0.9897, F1: 0.7830
# [Validate] Loss: 0.2250, Accuracy: 0.9552, Precision: 0.7015, Recall: 0.9722, F1: 0.7821
# Testing parameters: (64, 0.5, 2, 30)
# [Train] Epoch: 0, Loss: 1.3319, Accuracy: 0.4870, Precision: 0.0680, Recall: 0.3945, F1: 0.1074
# [Train] Epoch: 10, Loss: 0.2470, Accuracy: 0.9400, Precision: 0.6294, Recall: 0.9727, F1: 0.7250
# [Train] Epoch: 20, Loss: 0.2001, Accuracy: 0.9510, Precision: 0.6850, Recall: 0.9801, F1: 0.7704
# [Validate] Loss: 0.2255, Accuracy: 0.9497, Precision: 0.6850, Recall: 0.9666, F1: 0.7648
# Testing parameters: (64, 0.5, 2, 60)
# [Train] Epoch: 0, Loss: 1.3265, Accuracy: 0.4719, Precision: 0.0812, Recall: 0.4359, F1: 0.1219
# [Train] Epoch: 10, Loss: 0.2442, Accuracy: 0.9421, Precision: 0.6455, Recall: 0.9754, F1: 0.7398
# [Train] Epoch: 20, Loss: 0.1968, Accuracy: 0.9512, Precision: 0.6800, Recall: 0.9807, F1: 0.7684
# [Train] Epoch: 30, Loss: 0.1875, Accuracy: 0.9505, Precision: 0.6675, Recall: 0.9815, F1: 0.7629
# [Train] Epoch: 40, Loss: 0.1768, Accuracy: 0.9522, Precision: 0.6847, Recall: 0.9839, F1: 0.7742
# [Train] Epoch: 50, Loss: 0.1699, Accuracy: 0.9553, Precision: 0.7056, Recall: 0.9834, F1: 0.7905
# [Validate] Loss: 0.1900, Accuracy: 0.9567, Precision: 0.7315, Recall: 0.9734, F1: 0.8013
# Testing parameters: (64, 0.5, 4, 30)
# [Train] Epoch: 0, Loss: 1.3363, Accuracy: 0.4679, Precision: 0.0730, Recall: 0.2954, F1: 0.1097
# [Train] Epoch: 10, Loss: 0.2152, Accuracy: 0.9444, Precision: 0.6483, Recall: 0.9809, F1: 0.7432
# [Train] Epoch: 20, Loss: 0.1991, Accuracy: 0.9503, Precision: 0.6827, Recall: 0.9775, F1: 0.7679
# [Validate] Loss: 0.1970, Accuracy: 0.9480, Precision: 0.6742, Recall: 0.9817, F1: 0.7636
# Testing parameters: (64, 0.5, 4, 60)
# [Train] Epoch: 0, Loss: 1.3342, Accuracy: 0.3819, Precision: 0.0739, Recall: 0.6004, F1: 0.1156
# [Train] Epoch: 10, Loss: 0.2103, Accuracy: 0.9450, Precision: 0.6533, Recall: 0.9789, F1: 0.7459
# [Train] Epoch: 20, Loss: 0.1804, Accuracy: 0.9500, Precision: 0.6783, Recall: 0.9846, F1: 0.7687
# [Train] Epoch: 30, Loss: 0.1726, Accuracy: 0.9536, Precision: 0.6918, Recall: 0.9819, F1: 0.7770
# [Train] Epoch: 40, Loss: 0.1704, Accuracy: 0.9544, Precision: 0.7026, Recall: 0.9830, F1: 0.7863
# [Train] Epoch: 50, Loss: 0.1628, Accuracy: 0.9558, Precision: 0.7040, Recall: 0.9857, F1: 0.7905
# [Validate] Loss: 0.2475, Accuracy: 0.9570, Precision: 0.7399, Recall: 0.9741, F1: 0.8128
# Testing parameters: (64, 0.5, 8, 30)
# [Train] Epoch: 0, Loss: 1.3337, Accuracy: 0.5037, Precision: 0.0729, Recall: 0.4360, F1: 0.1107
# [Train] Epoch: 10, Loss: 0.2003, Accuracy: 0.9504, Precision: 0.6822, Recall: 0.9806, F1: 0.7688
# [Train] Epoch: 20, Loss: 0.1846, Accuracy: 0.9515, Precision: 0.6847, Recall: 0.9804, F1: 0.7723
# [Validate] Loss: 0.2038, Accuracy: 0.9515, Precision: 0.6878, Recall: 0.9714, F1: 0.7712
# Testing parameters: (64, 0.5, 8, 60)
# [Train] Epoch: 0, Loss: 1.3127, Accuracy: 0.5081, Precision: 0.0986, Recall: 0.5710, F1: 0.1506
# [Train] Epoch: 10, Loss: 0.1972, Accuracy: 0.9510, Precision: 0.6838, Recall: 0.9794, F1: 0.7705
# [Train] Epoch: 20, Loss: 0.1777, Accuracy: 0.9513, Precision: 0.6866, Recall: 0.9823, F1: 0.7731
# [Train] Epoch: 30, Loss: 0.1755, Accuracy: 0.9515, Precision: 0.6878, Recall: 0.9834, F1: 0.7744
# [Train] Epoch: 40, Loss: 0.1724, Accuracy: 0.9538, Precision: 0.6923, Recall: 0.9816, F1: 0.7783
# [Train] Epoch: 50, Loss: 0.1675, Accuracy: 0.9553, Precision: 0.6979, Recall: 0.9843, F1: 0.7839
# [Validate] Loss: 0.2052, Accuracy: 0.9559, Precision: 0.7042, Recall: 0.9732, F1: 0.7854
# Best parameters: (64, 0.5, 2, 60), with loss: 0.1900

# %%
# Pokreni testiranje sa najboljim parametrima
hidden_channels, dropout_rate, num_heads, num_epochs = best_params
print(f'Testing the best model with parameters: {best_params}')

# inicijalizacija modela sa najboljim parametrima
model = GAT(in_channels=node_features.shape[1], hidden_channels=hidden_channels, out_channels=labels.shape[1], dropout_rate=dropout_rate, num_heads=num_heads).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
criterion = torch.nn.BCEWithLogitsLoss(pos_weight=class_weights.to(device))

for epoch in range(num_epochs):
    loss_train, acc_train, precision_train, recall_train, f1_train = train()

test_loss, test_acc, test_precision, test_recall, test_f1 = evaluate(data.test_mask)

# prikaz rezultata na test skupu
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc:.4f}')
print(f'Test Precision: {test_precision:.4f}')
print(f'Test Recall: {test_recall:.4f}')
print(f'Test F1 Score: {test_f1:.4f}')
# Out:
# Testing the best model with parameters: (64, 0.5, 2, 60)
# Test Loss: 0.1982
# Test Accuracy: 0.9508
# Test Precision: 0.6966
# Test Recall: 0.9704
# Test F1 Score: 0.7746
